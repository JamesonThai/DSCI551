# %% [markdown]
# **For this notebook to work, the prompt command code needs to be "pyspark" instead of "jupyter notebook"**
#
# **Documentation:**
#
# * PySpark RDD: https://spark.apache.org/docs/2.2.0/api/python/pyspark.html#pyspark.RDD
#
# * PySpark SQL: https://spark.apache.org/docs/latest/sql-programming-guide.html
#
# * PySpark SQL DataFrame: https://spark.apache.org/docs/2.2.0/api/python/pyspark.sql.html#pyspark.sql.DataFrame

# %%
# Import pyspark.sql modules
from pyspark.sql import SparkSession, SQLContext, Row
from pyspark.sql.types import FloatType

# Packages to upload to firebase
import json
import requests

# %%
# URL for the Firebase database
database_url = 'https://neighborhood-score-la.firebaseio.com/.json'

# %%
# Clean Firebase database
requests.put(database_url, data=json.dumps(None))
# Out:
# <Response [200]>

# %%
# Initiate the sqlSession, sqlContext and get the link for the Spark UI
sqlSession = SparkSession.builder.master("local").appName("Neighborhood-Scorer").getOrCreate()
sqlContext = SQLContext(sc)
sqlContext.sparkSession
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Matheus-PC:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Load the Crime Dataset to PySpark and MapReduce to Aggregate Data

# %%
# Read the csv with neighborhood crime data
df1 = sqlContext.read.csv('Crime_Data_2019_Neighborhoods_v5.csv', header=True)
df1.show()
# Out:
# +---------+----------+--------------------+-------------------+
# |    DR_NO|  DATE OCC|        Neighborhood|Crime_Weighted_Norm|
# +---------+----------+--------------------+-------------------+
# |191907191|  3/8/2019|              Sylmar|        0.113706949|
# |190125334|10/17/2019|Downtown Los Angeles|        0.246650906|
# |191920961|12/22/2019|    North Hills East|        0.113706949|
# |190604395|  1/9/2019|          Central LA|        0.113706949|
# |191310615| 4/30/2019|   South Los Angeles|        0.113706949|
# |191419522|  9/3/2019|         Westchester|        0.113706949|
# |190123550| 9/21/2019|Downtown Los Angeles|        0.246650906|
# |191915118| 8/18/2019|              Sylmar|        0.113706949|
# |190811511| 6/20/2019|           Brentwood|        0.113706949|
# |191605013| 1/29/2019|          Sun Valley|        0.113706949|
# |190129579|12/18/2019|Downtown Los Angeles|        0.113706949|
# |191116816| 9/18/2019|Northeast Los Ang...|        0.057744638|
# |190220657|10/25/2019|            Westlake|        0.113706949|
# |191307997| 3/14/2019|Downtown Los Angeles|        0.246650906|
# |190211654| 5/19/2019|            Westlake|        0.113706949|
# |191919183|11/12/2019|              Arleta|        0.113706949|
# |191106587| 2/20/2019|       Highland Park|        0.113706949|
# |191309607| 4/10/2019|   South Los Angeles|        0.113706949|
# |190412442| 7/17/2019|     Lincoln Heights|         0.27095249|
# |191822844| 11/8/2019|Harbor Gateway North|        0.113706949|
# +---------+----------+--------------------+-------------------+
# only showing top 20 rows

# %%
# MapReduce to get the count of crimes per neighborhood
df2 = df1.groupBy('Neighborhood').count()
df2 = df2.withColumnRenamed('count', 'CrimeCount')
df2.show()
# Out:
# +--------------------+----------+
# |        Neighborhood|CrimeCount|
# +--------------------+----------+
# |           Mar Vista|      1364|
# |          West Hills|       793|
# |           Hollywood|       165|
# |       Glassell Park|       232|
# |    Pico - Robertson|       844|
# |              Harbor|       902|
# |            Mid City|      8345|
# |Downtown Los Angeles|     13409|
# |              Reseda|      2511|
# | Crescenta Highlands|         4|
# |    North of Montana|         2|
# |          Central LA|     24753|
# |          McLaughlin|       231|
# |       Culver - West|       303|
# |       Baldwin Hills|       142|
# |      Elysian Valley|        67|
# |          Eagle Rock|        10|
# |        Sunset Strip|        14|
# |        North Arroyo|         1|
# |        Century City|       465|
# +--------------------+----------+
# only showing top 20 rows

# %%
# MapReduce to the the average crime score per neighborhood
df3 = df1.groupBy('Neighborhood').agg({'Crime_Weighted_Norm': 'avg'})
df3 = df3.withColumnRenamed('avg(Crime_Weighted_Norm)', 'CrimeScore')
df3.show()
# Out:
# +--------------------+--------------------+
# |        Neighborhood|          CrimeScore|
# +--------------------+--------------------+
# |           Mar Vista|  0.1655460595469206|
# |          West Hills|  0.1577881623682219|
# |           Hollywood| 0.17064889600606062|
# |       Glassell Park| 0.13016096131896554|
# |    Pico - Robertson| 0.16039390652369653|
# |              Harbor| 0.16315045023059846|
# |            Mid City| 0.15981678633337423|
# |Downtown Los Angeles| 0.16958895540107172|
# |              Reseda| 0.14990767685384304|
# | Crescenta Highlands|        0.1956636565|
# |    North of Montana|0.022944957999999998|
# |          Central LA| 0.16590776860829162|
# |          McLaughlin| 0.13280403066666668|
# |       Culver - West|  0.1599755282871288|
# |       Baldwin Hills| 0.15898202638732392|
# |      Elysian Valley| 0.22014647929850756|
# |          Eagle Rock|        0.1659616953|
# |        Sunset Strip| 0.18806723907142858|
# |        North Arroyo|         0.037952846|
# |        Century City|  0.1710934649311828|
# +--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Load the House Dataset to PySpark and MapReduce to Aggregate Data

# %%
# Read the csv with neighborhood housing data
df4 = sqlContext.read.csv('neighborhood_housing_score.csv', header=True)
df4 = df4.withColumnRenamed('RegionName', 'Neighborhood')
df4.show()
# Out:
# +---+--------------------+--------+------------------+
# |_c0|        Neighborhood|SizeRank|     Housing_Score|
# +---+--------------------+--------+------------------+
# |  0|   South Los Angeles|       4|442013.57352941175|
# |  1|Southeast Los Ang...|       8| 367733.6911764706|
# |  2|           Hollywood|      18| 847758.7058823529|
# |  3|            Mid City|      62| 986030.0147058824|
# |  4|            Van Nuys|      64| 535259.6764705882|
# |  5|          Sun Valley|      68|513386.48529411765|
# |  6|          Northridge|      69| 670616.4705882353|
# |  7|              Sylmar|      74| 483452.1617647059|
# |  8|       Boyle Heights|      75| 424736.1617647059|
# |  9|     North Hollywood|      78| 613276.5441176471|
# | 10|           San Pedro|      79| 583256.8382352941|
# | 11|           Koreatown|      82| 629124.5441176471|
# | 12|      Woodland Hills|      83| 780429.2647058824|
# | 13|        Sherman Oaks|      85| 951315.7647058824|
# | 14|             Pacoima|      86|434265.85294117645|
# | 15|            Westlake|      99| 670293.2205882353|
# | 16|              Reseda|     100|501339.04411764705|
# | 17|       Panorama City|     112| 445110.4705882353|
# | 18|         Valley Glen|     131| 666177.4852941176|
# | 19|         North Hills|     136| 540003.9558823529|
# +---+--------------------+--------+------------------+
# only showing top 20 rows

# %%
# MapReduce to the the average size rank per neighborhood
df5 = df4.groupBy('Neighborhood').agg({'SizeRank': 'avg'})
df5 = df5.withColumnRenamed('avg(SizeRank)', 'SizeRank')
df5.show()
# Out:
# +----------------+--------+
# |    Neighborhood|SizeRank|
# +----------------+--------+
# |       Mar Vista|   238.0|
# | Harvard Heights|   413.0|
# |      West Hills|   288.0|
# |       Hollywood|    18.0|
# |   Glassell Park|   540.0|
# |        Mid City|    62.0|
# |          Reseda|   100.0|
# |         Del Rey|   331.0|
# |   Playa Del Rey|   886.0|
# |         Sunland|   866.0|
# |    Shadow Hills|  4441.0|
# |  Elysian Valley|  2819.0|
# |   Mid City West|   208.0|
# |      Eagle Rock|   382.0|
# |    Elysian Park| 11212.0|
# |    Century City|  3269.0|
# |      Pico-Union|   770.0|
# |       Brentwood|   360.0|
# |   Cheviot Hills|   988.0|
# |West Los Angeles|  1179.0|
# +----------------+--------+
# only showing top 20 rows

# %%
# MapReduce to the the average size rank per neighborhood
df6 = df4.groupBy('Neighborhood').agg({'Housing_Score': 'avg'})
df6 = df6.withColumnRenamed('avg(Housing_Score)', 'HousingScore')
df6.show()
# Out:
# +----------------+------------------+
# |    Neighborhood|      HousingScore|
# +----------------+------------------+
# |       Mar Vista|1330032.9411764706|
# | Harvard Heights| 681784.0735294118|
# |      West Hills| 662252.3382352941|
# |       Hollywood| 847758.7058823529|
# |   Glassell Park| 735981.5588235294|
# |        Mid City| 986030.0147058824|
# |          Reseda|501339.04411764705|
# |         Del Rey|1011292.3970588235|
# |   Playa Del Rey| 972849.4558823529|
# |         Sunland| 556602.8088235294|
# |    Shadow Hills| 715190.3529411765|
# |  Elysian Valley| 687034.6764705882|
# |   Mid City West|1532142.4117647058|
# |      Eagle Rock|         796614.25|
# |    Elysian Park| 590152.0735294118|
# |    Century City|1099622.0735294118|
# |      Pico-Union| 549041.7647058824|
# |       Brentwood|2223105.0588235296|
# |   Cheviot Hills|1664359.4117647058|
# |West Los Angeles| 1257659.455882353|
# +----------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### Load the School Dataset to PySpark and MapReduce to Aggregate Data

# %%
# Read the csv with neighborhood school data
df7 = sqlContext.read.csv('ACT19_LA_neighborhood_socre.csv', header=True)
df7 = df7.withColumnRenamed('RegionName', 'Neighborhood')
df7 = df7.withColumnRenamed('AVERAGE', 'AvgACT')
df7 = df7.withColumn("AvgScrRead", df7["AvgScrRead"].cast(FloatType()))
df7 = df7.withColumn("AvgScrEng", df7["AvgScrEng"].cast(FloatType()))
df7 = df7.withColumn("AvgScrRead", df7["AvgScrRead"].cast(FloatType()))
df7 = df7.withColumn("AvgScrMath", df7["AvgScrMath"].cast(FloatType()))
df7 = df7.withColumn("AvgScrSci", df7["AvgScrSci"].cast(FloatType()))
df7 = df7.withColumn("AvgACT", df7["AvgACT"].cast(FloatType()))
df7.show()
# Out:
# +--------------+----------+---------+----------+---------+---------+
# |  Neighborhood|AvgScrRead|AvgScrEng|AvgScrMath|AvgScrSci|   AvgACT|
# +--------------+----------+---------+----------+---------+---------+
# |  Agoura Hills|      27.0|     26.0|      25.0|     24.0|     25.5|
# |      Alhambra|      25.5|     26.0|      25.5|     24.5|   25.375|
# |     Allentown|      25.0|     24.0|      22.0|     23.0|     23.5|
# |       Arcadia|      28.0|     29.0|      28.0|     27.0|     28.0|
# |         Azusa|      17.0|     16.0|      18.0|     19.0|     17.5|
# |  Baldwin Park|      21.0|     19.0|      20.0|     20.0|     20.0|
# |       Bassett|      23.0|     22.0|      22.0|     22.0|    22.25|
# |          Bell|      18.0|     17.0|      18.0|     18.0|    17.75|
# | Beverly Hills|      28.0|     29.0|      27.0|     26.0|     27.5|
# |       Burbank|      25.5|     25.5|      24.5|     24.0|   24.875|
# |    California| 18.666666|16.666666| 17.666666|17.666666|17.666666|
# |   Canoga Park|      19.0|     18.0|      18.0|     18.0|    18.25|
# |      Carlsbad|      23.0|     23.0|      22.0|     22.0|     22.5|
# |        Carson| 21.333334|21.666666| 21.666666|20.333334|    21.25|
# |   Casa Grande|      24.0|     23.0|      23.0|     23.0|    23.25|
# |Castle Heights|      23.0|     23.0|      21.0|     21.0|     22.0|
# |    Central LA|      18.0|     17.4|      17.6|     17.8|     17.7|
# |      Cerritos|      24.0|     24.5|      25.0|     24.0|   24.375|
# |   Charter Oak|      22.0|     21.0|      22.0|     22.0|    21.75|
# |    Chatsworth|      21.0|     20.0|      21.0|     20.0|     20.5|
# +--------------+----------+---------+----------+---------+---------+
# only showing top 20 rows

# %% [markdown]
# ### Merge All Datasets Indexing by Neighborhood

# %%
# Join all dataframes by neighborhood
df_merged = df2.join(df3, 'Neighborhood', how='fullouter').join(df5, 'Neighborhood', how='fullouter').join(df6, 'Neighborhood', how='fullouter').join(df7, 'Neighborhood', how='fullouter')
df_merged.show()
# Out:
# +--------------------+----------+--------------------+--------+------------------+----------+---------+----------+---------+------+
# |        Neighborhood|CrimeCount|          CrimeScore|SizeRank|      HousingScore|AvgScrRead|AvgScrEng|AvgScrMath|AvgScrSci|AvgACT|
# +--------------------+----------+--------------------+--------+------------------+----------+---------+----------+---------+------+
# |     Harvard Heights|      null|                null|   413.0| 681784.0735294118|      null|     null|      null|     null|  null|
# |           Mar Vista|      1364|  0.1655460595469206|   238.0|1330032.9411764706|      null|     null|      null|     null|  null|
# |          West Hills|       793|  0.1577881623682219|   288.0| 662252.3382352941|      null|     null|      null|     null|  null|
# |       Glassell Park|       232| 0.13016096131896554|   540.0| 735981.5588235294|      null|     null|      null|     null|  null|
# |           Hollywood|       165| 0.17064889600606062|    18.0| 847758.7058823529|      null|     null|      null|     null|  null|
# |              Harbor|       902| 0.16315045023059846|    null|              null|      null|     null|      null|     null|  null|
# |             Maywood|      null|                null|    null|              null|      18.0|     16.0|      17.0|     18.0| 17.25|
# |    Pico - Robertson|       844| 0.16039390652369653|    null|              null|      null|     null|      null|     null|  null|
# |             Compton|      null|                null|    null|              null|      16.0|     14.4|      16.4|     15.8| 15.65|
# |            Westside|      null|                null|    null|              null|      18.0|     17.0|      18.0|     17.0|  17.5|
# |            Mid City|      8345| 0.15981678633337423|    62.0| 986030.0147058824|      27.0|     28.0|      28.0|     27.0|  27.5|
# |           Allentown|      null|                null|    null|              null|      25.0|     24.0|      22.0|     23.0|  23.5|
# |Downtown Los Angeles|     13409| 0.16958895540107172|    null|              null|      null|     null|      null|     null|  null|
# |              Reseda|      2511| 0.14990767685384304|   100.0|501339.04411764705|      26.0|     26.0|      24.0|     24.0|  25.0|
# | Crescenta Highlands|         4|        0.1956636565|    null|              null|      26.0|     27.0|      26.0|     25.0|  26.0|
# |                Bell|      null|                null|    null|              null|      18.0|     17.0|      18.0|     18.0| 17.75|
# |             Del Rey|      null|                null|   331.0|1011292.3970588235|      null|     null|      null|     null|  null|
# |    North of Montana|         2|0.022944957999999998|    null|              null|      null|     null|      null|     null|  null|
# |       Playa Del Rey|      null|                null|   886.0| 972849.4558823529|      null|     null|      null|     null|  null|
# |          Central LA|     24753| 0.16590776860829162|    null|              null|      18.0|     17.4|      17.6|     17.8|  17.7|
# +--------------------+----------+--------------------+--------+------------------+----------+---------+----------+---------+------+
# only showing top 20 rows

# %%
print(f'There are {df_merged.count()} neighborhoods in the dataset')
# Out:
# There are 224 neighborhoods in the dataset

# %% [markdown]
# ### MapReduce the PySpark DataFrame into a Dictionary
#
# This will be used as the data source for the creation of the jsons to be uploaded

# %%
# Convert from PySpark dataframe to json
json_data = df_merged.toJSON().collect()

# %%
# Read the json creating elements by neighborhood
list_data = [json.loads(json_data[i]) for i in range(len(json_data))]

# %%
# Extract the names of all neighborhoods and the features created
all_neighborhoods = [x.Neighborhood for x in df_merged.select('Neighborhood').distinct().collect()]
all_features = df_merged.columns[1:]

# %%
# First create a dict with index 1 being neighborhood and index 2 being each feature, with the values as None
# This is necessary to ensure all Neihgborhoods have all keys, which prevents problems down the line
dict_by_neighborhood = {}
for neigh in all_neighborhoods:
    dict_by_neighborhood[neigh] = {all_features[0]: None,
                                   all_features[1]: None,
                                   all_features[2]: None,
                                   all_features[3]: None,
                                   all_features[4]: None,
                                   all_features[5]: None,
                                   all_features[6]: None,
                                   all_features[7]: None,
                                   all_features[8]: None}

# %%
# Now fill each [Neighborhood][Feature] with the values existing in the data
# Missing values will remain as 'None'
for i in range(len(list_data)):
    for feat in all_features:      
        try:
            dict_by_neighborhood[list_data[i]['Neighborhood']][feat] = list_data[i][feat]
        except:
            pass

# %%
dict_by_neighborhood
# Out:
# {'Harvard Heights': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 413.0,
#   'HousingScore': 681784.0735294118,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Mar Vista': {'CrimeCount': 1364,
#   'CrimeScore': 0.1655460595469206,
#   'SizeRank': 238.0,
#   'HousingScore': 1330032.9411764706,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'West Hills': {'CrimeCount': 793,
#   'CrimeScore': 0.1577881623682219,
#   'SizeRank': 288.0,
#   'HousingScore': 662252.3382352941,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Glassell Park': {'CrimeCount': 232,
#   'CrimeScore': 0.13016096131896554,
#   'SizeRank': 540.0,
#   'HousingScore': 735981.5588235294,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Hollywood': {'CrimeCount': 165,
#   'CrimeScore': 0.17064889600606062,
#   'SizeRank': 18.0,
#   'HousingScore': 847758.7058823529,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Harbor': {'CrimeCount': 902,
#   'CrimeScore': 0.16315045023059846,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Maywood': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 18.0,
#   'AvgScrEng': 16.0,
#   'AvgScrMath': 17.0,
#   'AvgScrSci': 18.0,
#   'AvgACT': 17.25},
#  'Pico - Robertson': {'CrimeCount': 844,
#   'CrimeScore': 0.16039390652369653,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Compton': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 16.0,
#   'AvgScrEng': 14.4,
#   'AvgScrMath': 16.4,
#   'AvgScrSci': 15.8,
#   'AvgACT': 15.65},
#  'Westside': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 18.0,
#   'AvgScrEng': 17.0,
#   'AvgScrMath': 18.0,
#   'AvgScrSci': 17.0,
#   'AvgACT': 17.5},
#  'Mid City': {'CrimeCount': 8345,
#   'CrimeScore': 0.15981678633337423,
#   'SizeRank': 62.0,
#   'HousingScore': 986030.0147058824,
#   'AvgScrRead': 27.0,
#   'AvgScrEng': 28.0,
#   'AvgScrMath': 28.0,
#   'AvgScrSci': 27.0,
#   'AvgACT': 27.5},
#  'Allentown': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 25.0,
#   'AvgScrEng': 24.0,
#   'AvgScrMath': 22.0,
#   'AvgScrSci': 23.0,
#   'AvgACT': 23.5},
#  'Downtown Los Angeles': {'CrimeCount': 13409,
#   'CrimeScore': 0.16958895540107172,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Reseda': {'CrimeCount': 2511,
#   'CrimeScore': 0.14990767685384304,
#   'SizeRank': 100.0,
#   'HousingScore': 501339.04411764705,
#   'AvgScrRead': 26.0,
#   'AvgScrEng': 26.0,
#   'AvgScrMath': 24.0,
#   'AvgScrSci': 24.0,
#   'AvgACT': 25.0},
#  'Crescenta Highlands': {'CrimeCount': 4,
#   'CrimeScore': 0.1956636565,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 26.0,
#   'AvgScrEng': 27.0,
#   'AvgScrMath': 26.0,
#   'AvgScrSci': 25.0,
#   'AvgACT': 26.0},
#  'Bell': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 18.0,
#   'AvgScrEng': 17.0,
#   'AvgScrMath': 18.0,
#   'AvgScrSci': 18.0,
#   'AvgACT': 17.75},
#  'Del Rey': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 331.0,
#   'HousingScore': 1011292.3970588235,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'North of Montana': {'CrimeCount': 2,
#   'CrimeScore': 0.022944957999999998,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Playa Del Rey': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 886.0,
#   'HousingScore': 972849.4558823529,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Central LA': {'CrimeCount': 24753,
#   'CrimeScore': 0.16590776860829162,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 18.0,
#   'AvgScrEng': 17.4,
#   'AvgScrMath': 17.6,
#   'AvgScrSci': 17.8,
#   'AvgACT': 17.7},
#  'McLaughlin': {'CrimeCount': 231,
#   'CrimeScore': 0.13280403066666668,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Baldwin Hills': {'CrimeCount': 142,
#   'CrimeScore': 0.15898202638732392,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Culver - West': {'CrimeCount': 303,
#   'CrimeScore': 0.1599755282871288,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Shadow Hills': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 4441.0,
#   'HousingScore': 715190.3529411765,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Sunland': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 866.0,
#   'HousingScore': 556602.8088235294,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'San Fernando': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 17.5,
#   'AvgScrEng': 16.0,
#   'AvgScrMath': 17.5,
#   'AvgScrSci': 17.0,
#   'AvgACT': 17.0},
#  'Elysian Valley': {'CrimeCount': 67,
#   'CrimeScore': 0.22014647929850756,
#   'SizeRank': 2819.0,
#   'HousingScore': 687034.6764705882,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Eagle Rock': {'CrimeCount': 10,
#   'CrimeScore': 0.1659616953,
#   'SizeRank': 382.0,
#   'HousingScore': 796614.25,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Elysian Park': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 11212.0,
#   'HousingScore': 590152.0735294118,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Mid City West': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 208.0,
#   'HousingScore': 1532142.4117647058,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'North Arroyo': {'CrimeCount': 1,
#   'CrimeScore': 0.037952846,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Sunset Strip': {'CrimeCount': 14,
#   'CrimeScore': 0.18806723907142858,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Century City': {'CrimeCount': 465,
#   'CrimeScore': 0.1710934649311828,
#   'SizeRank': 3269.0,
#   'HousingScore': 1099622.0735294118,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Los Angeles': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 15.666667,
#   'AvgScrEng': 14.333333,
#   'AvgScrMath': 16.0,
#   'AvgScrSci': 16.666666,
#   'AvgACT': 15.666667},
#  'Pico-Union': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 770.0,
#   'HousingScore': 549041.7647058824,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Northeast Torrance': {'CrimeCount': 7,
#   'CrimeScore': 0.14357004157142855,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Brentwood': {'CrimeCount': 501,
#   'CrimeScore': 0.16343506594411164,
#   'SizeRank': 360.0,
#   'HousingScore': 2223105.0588235296,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Cheviot Hills': {'CrimeCount': 86,
#   'CrimeScore': 0.17973090304651163,
#   'SizeRank': 988.0,
#   'HousingScore': 1664359.4117647058,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Sunkist Park': {'CrimeCount': 1,
#   'CrimeScore': 0.00793707,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Pomona': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 20.4,
#   'AvgScrEng': 19.4,
#   'AvgScrMath': 19.4,
#   'AvgScrSci': 19.6,
#   'AvgACT': 19.7},
#  'Cypress Park': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 1502.0,
#   'HousingScore': 632183.9705882353,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'West Los Angeles': {'CrimeCount': 3323,
#   'CrimeScore': 0.16267852776497227,
#   'SizeRank': 1179.0,
#   'HousingScore': 1257659.455882353,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'South Carthay': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 5822.0,
#   'HousingScore': 1517561.6323529412,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Studio City': {'CrimeCount': 2041,
#   'CrimeScore': 0.1740775870480159,
#   'SizeRank': 298.0,
#   'HousingScore': 1100082.455882353,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Hacienda Heights': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 22.0,
#   'AvgScrMath': 22.5,
#   'AvgScrSci': 23.0,
#   'AvgACT': 22.625},
#  'Lynwood': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 18.0,
#   'AvgScrEng': 17.0,
#   'AvgScrMath': 17.0,
#   'AvgScrSci': 17.0,
#   'AvgACT': 17.25},
#  'Southeast Los Angeles': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 8.0,
#   'HousingScore': 367733.6911764706,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'North Central': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 18.0,
#   'AvgScrEng': 18.0,
#   'AvgScrMath': 18.0,
#   'AvgScrSci': 19.0,
#   'AvgACT': 18.25},
#  'Warner Center': {'CrimeCount': 309,
#   'CrimeScore': 0.17436356564077665,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Arcadia': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 28.0,
#   'AvgScrEng': 29.0,
#   'AvgScrMath': 28.0,
#   'AvgScrSci': 27.0,
#   'AvgACT': 28.0},
#  'Mandeville Canyon': {'CrimeCount': 2,
#   'CrimeScore': 0.1448282315,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Valley Village': {'CrimeCount': 735,
#   'CrimeScore': 0.16947354972516993,
#   'SizeRank': 456.0,
#   'HousingScore': 920222.5441176471,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Westlake North': {'CrimeCount': 150,
#   'CrimeScore': 0.17460695598666665,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 15.333333,
#   'AvgScrEng': 14.0,
#   'AvgScrMath': 16.0,
#   'AvgScrSci': 15.666667,
#   'AvgACT': 15.25},
#  'La Puente': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 22.0,
#   'AvgScrEng': 20.0,
#   'AvgScrMath': 21.0,
#   'AvgScrSci': 20.0,
#   'AvgACT': 20.75},
#  'Burbank': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 25.5,
#   'AvgScrEng': 25.5,
#   'AvgScrMath': 24.5,
#   'AvgScrSci': 24.0,
#   'AvgACT': 24.875},
#  'MacArthur Park': {'CrimeCount': 14,
#   'CrimeScore': 0.15030335792857144,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Rancho Park': {'CrimeCount': 187,
#   'CrimeScore': 0.1925642889304812,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Pico-Robertson': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 556.0,
#   'HousingScore': 1208496.5147058824,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Santa Monica Boulevard': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 19.0,
#   'AvgScrEng': 20.0,
#   'AvgScrMath': 18.0,
#   'AvgScrSci': 18.0,
#   'AvgACT': 18.75},
#  'Mission Hills': {'CrimeCount': 882,
#   'CrimeScore': 0.15076614886734677,
#   'SizeRank': 606.0,
#   'HousingScore': 501011.79411764705,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Tarzana': {'CrimeCount': 1780,
#   'CrimeScore': 0.171074785749438,
#   'SizeRank': 283.0,
#   'HousingScore': 798065.6176470588,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Cornwell Street': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 21.0,
#   'AvgScrEng': 20.0,
#   'AvgScrMath': 21.0,
#   'AvgScrSci': 20.0,
#   'AvgACT': 20.5},
#  'Crestview': {'CrimeCount': 6,
#   'CrimeScore': 0.137871235,
#   'SizeRank': 1663.0,
#   'HousingScore': 1116130.705882353,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'South Los Angeles': {'CrimeCount': 46983,
#   'CrimeScore': 0.17373907403648747,
#   'SizeRank': 4.0,
#   'HousingScore': 442013.57352941175,
#   'AvgScrRead': 16.75,
#   'AvgScrEng': 15.785714,
#   'AvgScrMath': 17.107143,
#   'AvgScrSci': 16.821428,
#   'AvgACT': 16.616072},
#  'Castle Heights': {'CrimeCount': 204,
#   'CrimeScore': 0.15612325411764705,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 23.0,
#   'AvgScrMath': 21.0,
#   'AvgScrSci': 21.0,
#   'AvgACT': 22.0},
#  'Venice': {'CrimeCount': 3540,
#   'CrimeScore': 0.1634441030387011,
#   'SizeRank': 351.0,
#   'HousingScore': 1587068.955882353,
#   'AvgScrRead': 17.0,
#   'AvgScrEng': 16.0,
#   'AvgScrMath': 17.0,
#   'AvgScrSci': 17.0,
#   'AvgACT': 16.75},
#  'Arlington Heights': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 1016.0,
#   'HousingScore': 826847.3823529412,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Lincoln Heights': {'CrimeCount': 1573,
#   'CrimeScore': 0.15562271093070562,
#   'SizeRank': 368.0,
#   'HousingScore': 517606.32352941175,
#   'AvgScrRead': 20.0,
#   'AvgScrEng': 19.5,
#   'AvgScrMath': 20.5,
#   'AvgScrSci': 20.5,
#   'AvgACT': 20.125},
#  'University Hills': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 2989.0,
#   'HousingScore': 509214.10294117645,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Panorama City': {'CrimeCount': 2421,
#   'CrimeScore': 0.15229802257992567,
#   'SizeRank': 112.0,
#   'HousingScore': 445110.4705882353,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Van Nuys': {'CrimeCount': 7491,
#   'CrimeScore': 0.15276185838740008,
#   'SizeRank': 64.0,
#   'HousingScore': 535259.6764705882,
#   'AvgScrRead': 21.0,
#   'AvgScrEng': 20.5,
#   'AvgScrMath': 19.0,
#   'AvgScrSci': 19.5,
#   'AvgACT': 20.0},
#  'Casa Grande': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 24.0,
#   'AvgScrEng': 23.0,
#   'AvgScrMath': 23.0,
#   'AvgScrSci': 23.0,
#   'AvgACT': 23.25},
#  'Hawthorne': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 19.0,
#   'AvgScrEng': 18.5,
#   'AvgScrMath': 19.0,
#   'AvgScrSci': 18.0,
#   'AvgACT': 18.625},
#  'Carson': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 21.333334,
#   'AvgScrEng': 21.666666,
#   'AvgScrMath': 21.666666,
#   'AvgScrSci': 20.333334,
#   'AvgACT': 21.25},
#  'Pasadena': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 22.0,
#   'AvgScrMath': 22.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 22.25},
#  'Sunset Park': {'CrimeCount': 12,
#   'CrimeScore': 0.1990840451666667,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Hollywood Hills': {'CrimeCount': 63,
#   'CrimeScore': 0.17519179882539684,
#   'SizeRank': 333.0,
#   'HousingScore': 1452064.1764705882,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Agoura Hills': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 27.0,
#   'AvgScrEng': 26.0,
#   'AvgScrMath': 25.0,
#   'AvgScrSci': 24.0,
#   'AvgACT': 25.5},
#  'La Cañada Flintridge': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 29.0,
#   'AvgScrEng': 29.0,
#   'AvgScrMath': 29.0,
#   'AvgScrSci': 28.0,
#   'AvgACT': 28.75},
#  'Rowland Heights': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 25.0,
#   'AvgScrEng': 25.0,
#   'AvgScrMath': 26.0,
#   'AvgScrSci': 25.0,
#   'AvgACT': 25.25},
#  'El Sereno': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 219.0,
#   'HousingScore': 542633.4264705882,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Vermont Vista': {'CrimeCount': 36,
#   'CrimeScore': 0.2292794035555555,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Playa Vista': {'CrimeCount': 336,
#   'CrimeScore': 0.16667728641666657,
#   'SizeRank': 3731.0,
#   'HousingScore': 993017.5294117647,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Pacoima': {'CrimeCount': 2966,
#   'CrimeScore': 0.14354808568948083,
#   'SizeRank': 86.0,
#   'HousingScore': 434265.85294117645,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Silver Lake': {'CrimeCount': 1813,
#   'CrimeScore': 0.17181418235907314,
#   'SizeRank': 296.0,
#   'HousingScore': 879257.2058823529,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Manhattan Beach': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 28.0,
#   'AvgScrEng': 28.0,
#   'AvgScrMath': 27.0,
#   'AvgScrSci': 27.0,
#   'AvgACT': 27.5},
#  'Inglewood': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 17.2,
#   'AvgScrEng': 16.2,
#   'AvgScrMath': 17.2,
#   'AvgScrSci': 17.0,
#   'AvgACT': 16.9},
#  'Beverlywood': {'CrimeCount': 243,
#   'CrimeScore': 0.1644660786995884,
#   'SizeRank': 2003.0,
#   'HousingScore': 1450204.5735294118,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Chinatown': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 2087.0,
#   'HousingScore': 522933.8088235294,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Lakewood': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 22.0,
#   'AvgScrEng': 21.0,
#   'AvgScrMath': 21.0,
#   'AvgScrSci': 21.0,
#   'AvgACT': 21.25},
#  'South Montebello': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 18.666666,
#   'AvgScrEng': 17.666666,
#   'AvgScrMath': 17.333334,
#   'AvgScrSci': 18.333334,
#   'AvgACT': 18.0},
#  'Duarte': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 23.5,
#   'AvgScrEng': 23.5,
#   'AvgScrMath': 21.0,
#   'AvgScrSci': 21.5,
#   'AvgACT': 22.375},
#  'The Flats': {'CrimeCount': 1,
#   'CrimeScore': 0.27095249,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Echo Park': {'CrimeCount': 1902,
#   'CrimeScore': 0.1682831438617243,
#   'SizeRank': 529.0,
#   'HousingScore': 714715.4705882353,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Lawndale': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 18.0,
#   'AvgScrEng': 17.0,
#   'AvgScrMath': 17.0,
#   'AvgScrSci': 17.5,
#   'AvgACT': 17.375},
#  'Montecito Heights': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 2365.0,
#   'HousingScore': 587410.7058823529,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Harbor Gateway': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 255.0,
#   'HousingScore': 507412.17647058825,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Lancaster': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 20.0,
#   'AvgScrEng': 19.5,
#   'AvgScrMath': 17.5,
#   'AvgScrSci': 19.0,
#   'AvgACT': 19.0},
#  'Park West': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 24.0,
#   'AvgScrEng': 24.0,
#   'AvgScrMath': 22.0,
#   'AvgScrSci': 23.0,
#   'AvgACT': 23.25},
#  'San Pedro': {'CrimeCount': 3754,
#   'CrimeScore': 0.15231965121070898,
#   'SizeRank': 79.0,
#   'HousingScore': 583256.8382352941,
#   'AvgScrRead': 17.0,
#   'AvgScrEng': 16.0,
#   'AvgScrMath': 17.0,
#   'AvgScrSci': 18.0,
#   'AvgACT': 17.0},
#  'Boyle Heights': {'CrimeCount': 11,
#   'CrimeScore': 0.18373525027272725,
#   'SizeRank': 75.0,
#   'HousingScore': 424736.1617647059,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Wilmington': {'CrimeCount': 2797,
#   'CrimeScore': 0.1634325842352523,
#   'SizeRank': 155.0,
#   'HousingScore': 427341.98529411765,
#   'AvgScrRead': 25.0,
#   'AvgScrEng': 25.0,
#   'AvgScrMath': 23.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 23.75},
#  'Granada Hills': {'CrimeCount': 1857,
#   'CrimeScore': 0.16005245692837886,
#   'SizeRank': 184.0,
#   'HousingScore': 616410.3382352941,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 22.5,
#   'AvgScrMath': 22.5,
#   'AvgScrSci': 22.0,
#   'AvgACT': 22.5},
#  'Toy District': {'CrimeCount': 435,
#   'CrimeScore': 0.17705082382988518,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Charter Oak': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 22.0,
#   'AvgScrEng': 21.0,
#   'AvgScrMath': 22.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 21.75},
#  'Harbor Gateway North': {'CrimeCount': 1227,
#   'CrimeScore': 0.16992421445395253,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 17.5,
#   'AvgScrEng': 17.0,
#   'AvgScrMath': 17.5,
#   'AvgScrSci': 17.0,
#   'AvgACT': 17.25},
#  'Hollywoodland': {'CrimeCount': 1,
#   'CrimeScore': 0.246650906,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Little Ethiopia': {'CrimeCount': 12,
#   'CrimeScore': 0.11600177808333334,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'North Hills': {'CrimeCount': 2074,
#   'CrimeScore': 0.1446696531070395,
#   'SizeRank': 136.0,
#   'HousingScore': 540003.9558823529,
#   'AvgScrRead': 20.0,
#   'AvgScrEng': 19.0,
#   'AvgScrMath': 20.0,
#   'AvgScrSci': 19.0,
#   'AvgACT': 19.5},
#  'Porter Ranch': {'CrimeCount': 213,
#   'CrimeScore': 0.17229200457276994,
#   'SizeRank': 559.0,
#   'HousingScore': 764179.5441176471,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Lake Balboa': {'CrimeCount': 656,
#   'CrimeScore': 0.1605837834435975,
#   'SizeRank': 199.0,
#   'HousingScore': 552609.4558823529,
#   'AvgScrRead': 22.0,
#   'AvgScrEng': 22.5,
#   'AvgScrMath': 21.5,
#   'AvgScrSci': 21.0,
#   'AvgACT': 21.75},
#  'Windsor Hills': {'CrimeCount': 1,
#   'CrimeScore': 0.057744638,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Watts': {'CrimeCount': 12,
#   'CrimeScore': 0.1290179655,
#   'SizeRank': 253.0,
#   'HousingScore': 340643.3676470588,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Saugus': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 25.0,
#   'AvgScrEng': 23.0,
#   'AvgScrMath': 21.0,
#   'AvgScrSci': 23.0,
#   'AvgACT': 23.0},
#  'Palms': {'CrimeCount': 1595,
#   'CrimeScore': 0.1636557849836988,
#   'SizeRank': 217.0,
#   'HousingScore': 1073720.6911764706,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Playa del Rey': {'CrimeCount': 705,
#   'CrimeScore': 0.1666010991375885,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'North Hills West': {'CrimeCount': 3,
#   'CrimeScore': 0.12871996966666668,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'East Whitter': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 22.0,
#   'AvgScrMath': 23.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 22.5},
#  'Park Mesa Heights': {'CrimeCount': 23,
#   'CrimeScore': 0.12110269391304347,
#   'SizeRank': 330.0,
#   'HousingScore': 528223.4117647059,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Spaulding Square': {'CrimeCount': 11,
#   'CrimeScore': 0.1775318579090909,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Sun Valley': {'CrimeCount': 2423,
#   'CrimeScore': 0.15852584558233623,
#   'SizeRank': 68.0,
#   'HousingScore': 513386.48529411765,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 22.0,
#   'AvgScrMath': 24.0,
#   'AvgScrSci': 23.0,
#   'AvgACT': 23.0},
#  'Crenshaw': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 493.0,
#   'HousingScore': 730864.25,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Old Town Torrance': {'CrimeCount': 26,
#   'CrimeScore': 0.12888550146153846,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'El Rancho': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 19.0,
#   'AvgScrEng': 18.0,
#   'AvgScrMath': 19.0,
#   'AvgScrSci': 19.0,
#   'AvgACT': 18.75},
#  'Lake View Terrace': {'CrimeCount': 56,
#   'CrimeScore': 0.16738434882142858,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Long Beach': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 24.0,
#   'AvgScrEng': 24.0,
#   'AvgScrMath': 22.0,
#   'AvgScrSci': 23.0,
#   'AvgACT': 23.25},
#  'Leimert Park': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 1525.0,
#   'HousingScore': 677779.3970588235,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Arleta': {'CrimeCount': 994,
#   'CrimeScore': 0.15296287056438615,
#   'SizeRank': 295.0,
#   'HousingScore': 477057.57352941175,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Beverly Crest': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 1200.0,
#   'HousingScore': 2064603.75,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'South Beverly Park': {'CrimeCount': 2,
#   'CrimeScore': 0.0239548055,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Western Malibu': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 26.0,
#   'AvgScrEng': 26.0,
#   'AvgScrMath': 24.0,
#   'AvgScrSci': 24.0,
#   'AvgACT': 25.0},
#  'Central City': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 165.0,
#   'HousingScore': 396210.2205882353,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Northridge': {'CrimeCount': 4082,
#   'CrimeScore': 0.16083573644659602,
#   'SizeRank': 69.0,
#   'HousingScore': 670616.4705882353,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Southeast Torrance': {'CrimeCount': 1,
#   'CrimeScore': 0.068542814,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Mid Wilshire': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 258.0,
#   'HousingScore': 1277546.5,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Citrus Grove': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 22.0,
#   'AvgScrMath': 23.0,
#   'AvgScrSci': 23.0,
#   'AvgACT': 22.75},
#  'Sherwood Forest': {'CrimeCount': 1,
#   'CrimeScore': 0.234500114,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Art District': {'CrimeCount': 114,
#   'CrimeScore': 0.14644047399122806,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Cerritos': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 24.0,
#   'AvgScrEng': 24.5,
#   'AvgScrMath': 25.0,
#   'AvgScrSci': 24.0,
#   'AvgACT': 24.375},
#  'Koreatown': {'CrimeCount': 2423,
#   'CrimeScore': 0.15739727017086264,
#   'SizeRank': 82.0,
#   'HousingScore': 629124.5441176471,
#   'AvgScrRead': 22.0,
#   'AvgScrEng': 22.0,
#   'AvgScrMath': 18.0,
#   'AvgScrSci': 20.0,
#   'AvgACT': 20.5},
#  'Melrose': {'CrimeCount': 661,
#   'CrimeScore': 0.18943377586686827,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Westchester': {'CrimeCount': 4111,
#   'CrimeScore': 0.15299068292751353,
#   'SizeRank': 301.0,
#   'HousingScore': 1044847.6323529412,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Harbor City': {'CrimeCount': 917,
#   'CrimeScore': 0.16199439786368583,
#   'SizeRank': 488.0,
#   'HousingScore': 524653.2352941176,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Morningside Park': {'CrimeCount': 4,
#   'CrimeScore': 0.23126924875,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Ocean Park': {'CrimeCount': 9,
#   'CrimeScore': 0.18473996044444446,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Baldwin Park': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 21.0,
#   'AvgScrEng': 19.0,
#   'AvgScrMath': 20.0,
#   'AvgScrSci': 20.0,
#   'AvgACT': 20.0},
#  'Downtown': {'CrimeCount': 2,
#   'CrimeScore': 0.265218159,
#   'SizeRank': 312.0,
#   'HousingScore': 646193.5147058824,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Glendora': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 25.0,
#   'AvgScrEng': 23.0,
#   'AvgScrMath': 24.0,
#   'AvgScrSci': 23.0,
#   'AvgACT': 23.75},
#  'Sunland-Tujunga': {'CrimeCount': 609,
#   'CrimeScore': 0.15124805229064034,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Wilshire Center': {'CrimeCount': 1009,
#   'CrimeScore': 0.16376865306045588,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Jefferson Park': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 379.0,
#   'HousingScore': 663411.6323529412,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Los Angeles County': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 26.0,
#   'AvgScrEng': 26.0,
#   'AvgScrMath': 21.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 23.75},
#  'Monrovia': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 21.0,
#   'AvgScrEng': 19.0,
#   'AvgScrMath': 19.0,
#   'AvgScrSci': 19.0,
#   'AvgACT': 19.5},
#  'Winnetka': {'CrimeCount': 1226,
#   'CrimeScore': 0.16332854953181064,
#   'SizeRank': 195.0,
#   'HousingScore': 532137.7205882353,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Pacific Palisades': {'CrimeCount': 647,
#   'CrimeScore': 0.15830282618238,
#   'SizeRank': 538.0,
#   'HousingScore': 2861638.970588235,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Westlake': {'CrimeCount': 6625,
#   'CrimeScore': 0.175198779381435,
#   'SizeRank': 99.0,
#   'HousingScore': 670293.2205882353,
#   'AvgScrRead': 17.833334,
#   'AvgScrEng': 16.666666,
#   'AvgScrMath': 17.666666,
#   'AvgScrSci': 17.333334,
#   'AvgACT': 17.375},
#  'Greater Mulwood': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 27.0,
#   'AvgScrEng': 28.0,
#   'AvgScrMath': 25.0,
#   'AvgScrSci': 25.0,
#   'AvgACT': 26.25},
#  'Tropico': {'CrimeCount': 5,
#   'CrimeScore': 0.21706208600000002,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'East Los Angeles': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 17.5,
#   'AvgScrEng': 16.5,
#   'AvgScrMath': 18.5,
#   'AvgScrSci': 17.5,
#   'AvgACT': 17.5},
#  'Diamond Bar': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 28.0,
#   'AvgScrEng': 28.0,
#   'AvgScrMath': 29.0,
#   'AvgScrSci': 27.0,
#   'AvgACT': 28.0},
#  'Mount Washington': {'CrimeCount': 303,
#   'CrimeScore': 0.16027050379207924,
#   'SizeRank': 750.0,
#   'HousingScore': 748575.5441176471,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'East Hollywood': {'CrimeCount': 2265,
#   'CrimeScore': 0.15975429756953635,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Highland Park': {'CrimeCount': 774,
#   'CrimeScore': 0.1494910935284238,
#   'SizeRank': 181.0,
#   'HousingScore': 715496.7058823529,
#   'AvgScrRead': 16.5,
#   'AvgScrEng': 16.0,
#   'AvgScrMath': 18.0,
#   'AvgScrSci': 17.0,
#   'AvgACT': 16.875},
#  'Mid-City': {'CrimeCount': 12,
#   'CrimeScore': 0.16483351483333333,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'North Hills East': {'CrimeCount': 264,
#   'CrimeScore': 0.16835868080303035,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'La Mirada': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 24.0,
#   'AvgScrEng': 23.0,
#   'AvgScrMath': 21.0,
#   'AvgScrSci': 21.0,
#   'AvgACT': 22.25},
#  'Tujunga': {'CrimeCount': 741,
#   'CrimeScore': 0.15476260905937916,
#   'SizeRank': 457.0,
#   'HousingScore': 596466.4411764706,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'West Toluca Lake': {'CrimeCount': 6,
#   'CrimeScore': 0.11127903750000001,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Adams-Normandie': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 645.0,
#   'HousingScore': 649707.2352941176,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'La Verne': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 22.0,
#   'AvgScrMath': 22.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 22.25},
#  'Chatsworth': {'CrimeCount': 1675,
#   'CrimeScore': 0.15276175328179079,
#   'SizeRank': 304.0,
#   'HousingScore': 606482.0882352941,
#   'AvgScrRead': 21.0,
#   'AvgScrEng': 20.0,
#   'AvgScrMath': 21.0,
#   'AvgScrSci': 20.0,
#   'AvgACT': 20.5},
#  'Alhambra': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 25.5,
#   'AvgScrEng': 26.0,
#   'AvgScrMath': 25.5,
#   'AvgScrSci': 24.5,
#   'AvgACT': 25.375},
#  'NoHo Arts District': {'CrimeCount': 329,
#   'CrimeScore': 0.1788605440273556,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Carlsbad': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 23.0,
#   'AvgScrMath': 22.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 22.5},
#  'Pico Union': {'CrimeCount': 31,
#   'CrimeScore': 0.1331427938064516,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Valencia': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 29.0,
#   'AvgScrEng': 29.0,
#   'AvgScrMath': 25.0,
#   'AvgScrSci': 25.0,
#   'AvgACT': 27.0},
#  'Monte Mar Vista': {'CrimeCount': 11,
#   'CrimeScore': 0.20981417245454548,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Sherman Oaks': {'CrimeCount': 3502,
#   'CrimeScore': 0.16575678491690599,
#   'SizeRank': 85.0,
#   'HousingScore': 951315.7647058824,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Westwood': {'CrimeCount': 1455,
#   'CrimeScore': 0.15686441210721613,
#   'SizeRank': 160.0,
#   'HousingScore': 1286646.5294117648,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Holmby Hills': {'CrimeCount': 33,
#   'CrimeScore': 0.15107187275757578,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Claremont': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 25.0,
#   'AvgScrEng': 24.0,
#   'AvgScrMath': 24.0,
#   'AvgScrSci': 24.0,
#   'AvgACT': 24.25},
#  'Valley Glen': {'CrimeCount': 700,
#   'CrimeScore': 0.1559832720714285,
#   'SizeRank': 131.0,
#   'HousingScore': 666177.4852941176,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Beverly Glen': {'CrimeCount': 216,
#   'CrimeScore': 0.16259879737499994,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Palmdale': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 22.0,
#   'AvgScrEng': 21.0,
#   'AvgScrMath': 19.0,
#   'AvgScrSci': 20.0,
#   'AvgACT': 20.5},
#  'Bassett': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 22.0,
#   'AvgScrMath': 22.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 22.25},
#  'Encino': {'CrimeCount': 1827,
#   'CrimeScore': 0.17779791148221108,
#   'SizeRank': 201.0,
#   'HousingScore': 1066268.5294117648,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Fairfax': {'CrimeCount': 1470,
#   'CrimeScore': 0.1823483571190473,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 21.0,
#   'AvgScrEng': 20.5,
#   'AvgScrMath': 20.5,
#   'AvgScrSci': 20.0,
#   'AvgACT': 20.5},
#  'Los Altos': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 24.0,
#   'AvgScrEng': 23.0,
#   'AvgScrMath': 23.0,
#   'AvgScrSci': 23.0,
#   'AvgACT': 23.25},
#  'Woodland Hills': {'CrimeCount': 3697,
#   'CrimeScore': 0.17093814032972818,
#   'SizeRank': 83.0,
#   'HousingScore': 780429.2647058824,
#   'AvgScrRead': 25.0,
#   'AvgScrEng': 26.0,
#   'AvgScrMath': 25.0,
#   'AvgScrSci': 24.0,
#   'AvgACT': 25.0},
#  'Newport Beach': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 17.0,
#   'AvgScrEng': 16.0,
#   'AvgScrMath': 17.0,
#   'AvgScrSci': 17.0,
#   'AvgACT': 16.75},
#  'Hermon': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 5805.0,
#   'HousingScore': 670176.9558823529,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'San Gabriel': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 28.0,
#   'AvgScrEng': 28.0,
#   'AvgScrMath': 26.0,
#   'AvgScrSci': 26.0,
#   'AvgACT': 27.0},
#  'Oakwood': {'CrimeCount': 21,
#   'CrimeScore': 0.21169998628571426,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Norwalk': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 16.0,
#   'AvgScrEng': 16.0,
#   'AvgScrMath': 17.0,
#   'AvgScrSci': 17.0,
#   'AvgACT': 16.5},
#  'Toluca Lake': {'CrimeCount': 230,
#   'CrimeScore': 0.16849504618695646,
#   'SizeRank': 1780.0,
#   'HousingScore': 921505.5882352941,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Reynier Village': {'CrimeCount': 26,
#   'CrimeScore': 0.16897719134615385,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Sawtelle': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 338.0,
#   'HousingScore': 907221.2941176471,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Washington Culver': {'CrimeCount': 1,
#   'CrimeScore': 0.069179245,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Central City East': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 628.0,
#   'HousingScore': 640346.5147058824,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Northeast Los Angeles': {'CrimeCount': 6026,
#   'CrimeScore': 0.15279561621805637,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 19.25,
#   'AvgScrEng': 18.75,
#   'AvgScrMath': 19.0,
#   'AvgScrSci': 19.0,
#   'AvgACT': 19.0},
#  'Lakeview Terrace': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 1113.0,
#   'HousingScore': 513551.5882352941,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Covina': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 21.0,
#   'AvgScrEng': 21.0,
#   'AvgScrMath': 21.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 21.25},
#  'Fox Hills': {'CrimeCount': 1,
#   'CrimeScore': 0.165934932,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'California': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 18.666666,
#   'AvgScrEng': 16.666666,
#   'AvgScrMath': 17.666666,
#   'AvgScrSci': 17.666666,
#   'AvgACT': 17.666666},
#  'Beverly Hills': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 28.0,
#   'AvgScrEng': 29.0,
#   'AvgScrMath': 27.0,
#   'AvgScrSci': 26.0,
#   'AvgACT': 27.5},
#  'La Crescenta-Montrose': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 27.0,
#   'AvgScrEng': 27.0,
#   'AvgScrMath': 26.0,
#   'AvgScrSci': 26.0,
#   'AvgACT': 26.5},
#  'El Monte': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 22.0,
#   'AvgScrEng': 21.0,
#   'AvgScrMath': 23.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 22.0},
#  'South Gate': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 19.0,
#   'AvgScrEng': 18.0,
#   'AvgScrMath': 18.0,
#   'AvgScrSci': 18.0,
#   'AvgACT': 18.25},
#  'Bel Air': {'CrimeCount': 250,
#   'CrimeScore': 0.15469564896,
#   'SizeRank': 2260.0,
#   'HousingScore': 3048066.8235294116,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'University Park': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 452.0,
#   'HousingScore': 635890.4117647059,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Azusa': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 17.0,
#   'AvgScrEng': 16.0,
#   'AvgScrMath': 18.0,
#   'AvgScrSci': 19.0,
#   'AvgACT': 17.5},
#  'Mountain View': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 21.0,
#   'AvgScrEng': 19.0,
#   'AvgScrMath': 19.0,
#   'AvgScrSci': 19.0,
#   'AvgACT': 19.5},
#  'Huntington Park': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 16.5,
#   'AvgScrEng': 16.666666,
#   'AvgScrMath': 17.333334,
#   'AvgScrSci': 17.166666,
#   'AvgACT': 16.916666},
#  'West Adams': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 502.0,
#   'HousingScore': 659571.9264705882,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'North Hollywood': {'CrimeCount': 7730,
#   'CrimeScore': 0.15523250564269345,
#   'SizeRank': 78.0,
#   'HousingScore': 613276.5441176471,
#   'AvgScrRead': 16.0,
#   'AvgScrEng': 15.0,
#   'AvgScrMath': 16.0,
#   'AvgScrSci': 17.0,
#   'AvgACT': 16.0},
#  'Downey': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 23.0,
#   'AvgScrEng': 22.0,
#   'AvgScrMath': 22.0,
#   'AvgScrSci': 22.0,
#   'AvgACT': 22.25},
#  'Sylmar': {'CrimeCount': 2863,
#   'CrimeScore': 0.15504103311491452,
#   'SizeRank': 74.0,
#   'HousingScore': 483452.1617647059,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'La Tuna Canyon': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 7118.0,
#   'HousingScore': 729707.75,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Atwater Village': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 1374.0,
#   'HousingScore': 851465.0294117647,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'Canoga Park': {'CrimeCount': 4129,
#   'CrimeScore': 0.15704859267159202,
#   'SizeRank': 157.0,
#   'HousingScore': 487663.3823529412,
#   'AvgScrRead': 19.0,
#   'AvgScrEng': 18.0,
#   'AvgScrMath': 18.0,
#   'AvgScrSci': 18.0,
#   'AvgACT': 18.25},
#  'Littlerock': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 16.0,
#   'AvgScrEng': 15.0,
#   'AvgScrMath': 16.0,
#   'AvgScrSci': 16.0,
#   'AvgACT': 15.75},
#  'Vineyard': {'CrimeCount': 1,
#   'CrimeScore': 0.165934932,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None},
#  'El Segundo': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': None,
#   'HousingScore': None,
#   'AvgScrRead': 25.0,
#   'AvgScrEng': 25.0,
#   'AvgScrMath': 24.0,
#   'AvgScrSci': 24.0,
#   'AvgACT': 24.5},
#  'Los Feliz': {'CrimeCount': None,
#   'CrimeScore': None,
#   'SizeRank': 440.0,
#   'HousingScore': 1182677.8382352942,
#   'AvgScrRead': None,
#   'AvgScrEng': None,
#   'AvgScrMath': None,
#   'AvgScrSci': None,
#   'AvgACT': None}}

# %% [markdown]
# '# Convert the PySpark Distributed Dataframe to a list of dictionaries to the uploaded to firebase
# dict_by_neighborhood = df_merged.rdd.map(lambda x: {x['Neighborhood']: {'CrimeCount': x['CrimeCount'],
#                                                                         'CrimeScore': x['CrimeScore'],
#                                                                         'SizeRank': x['SizeRank'],
#                                                                         'HousingScore': x['HousingScore'],
#                                                                         'AvgScrRead': x['AvgScrRead'],
#                                                                         'AvgScrEng': x['AvgScrEng'],
#                                                                         'AvgScrMath': x['AvgScrMath'],
#                                                                         'AvgScrSci': x['AvgScrSci'],
#                                                                         'AvgACT': x['AvgACT']}}).collect()

# %% [markdown]
# ### Create the Dictionaries to be Uploaded to Firebase

# %%
# Create dataset with all data for each neighborhood 
final_neighborhood = {'NeighborhoodData': dict_by_neighborhood}

# %%
# Create a dictionary with CrimeCount per Neighborhood
CrimeCount_dict = {i:dict_by_neighborhood[i]['CrimeCount'] for i in dict_by_neighborhood}
final_CrimeCount = {'CrimeCount': CrimeCount_dict}

# %%
# Create a dictionary with CrimeScore per Neighborhood
CrimeScore_dict = {i:dict_by_neighborhood[i]['CrimeScore'] for i in dict_by_neighborhood}
final_CrimeScore = {'CrimeScore': CrimeScore_dict}

# %%
# Create a dictionary with SizeRank per Neighborhood
SizeRank_dict = {i:dict_by_neighborhood[i]['SizeRank'] for i in dict_by_neighborhood}
final_SizeRank = {'SizeRank': SizeRank_dict}

# %%
# Create a dictionary with HousingScore per Neighborhood
HousingScore_dict = {i:dict_by_neighborhood[i]['HousingScore'] for i in dict_by_neighborhood}
final_HousingScore = {'HousingScore': HousingScore_dict}

# %%
# Create a dictionary with AvgScrRead per Neighborhood
AvgScrRead_dict = {i:dict_by_neighborhood[i]['AvgScrRead'] for i in dict_by_neighborhood}
final_AvgScrRead = {'AvgScrRead': AvgScrRead_dict}

# %%
# Create a dictionary with AvgScrEng per Neighborhood
AvgScrEng_dict = {i:dict_by_neighborhood[i]['AvgScrEng'] for i in dict_by_neighborhood}
final_AvgScrEng = {'AvgScrEng': AvgScrEng_dict}

# %%
# Create a dictionary with AvgScrMath per Neighborhood
AvgScrMath_dict = {i:dict_by_neighborhood[i]['AvgScrMath'] for i in dict_by_neighborhood}
final_AvgScrMath = {'AvgScrMath': AvgScrMath_dict}

# %%
# Create a dictionary with AvgScrSci per Neighborhood
AvgScrSci_dict = {i:dict_by_neighborhood[i]['AvgScrSci'] for i in dict_by_neighborhood}
final_AvgScrSci = {'AvgScrSci': AvgScrSci_dict}

# %%
# Create a dictionary with AvgACT per Neighborhood
AvgACT_dict = {i:dict_by_neighborhood[i]['AvgACT'] for i in dict_by_neighborhood}
final_AvgACT = {'AvgACT': AvgACT_dict}

# %% [markdown]
# ### Upload Data to Firebase

# %%
# Patch the Neighborhood Data
patch_neighborhood = requests.patch(database_url, data=json.dumps(final_neighborhood))
print(f'Patching Neighborhood Data: {patch_neighborhood.reason}')
# Out:
# Patching Neighborhood Data: OK

# %%
# Patch the CrimeCount Dictionary
patch_crimecount = requests.patch(database_url, data=json.dumps(final_CrimeCount))
print(f'Patching CrimeCount Data: {patch_crimecount.reason}')
# Out:
# Patching CrimeCount Data: OK

# %%
# Patch the CrimeScore Dictionary
patch_crimescore = requests.patch(database_url, data=json.dumps(final_CrimeScore))
print(f'Patching CrimeScore Data: {patch_crimescore.reason}')
# Out:
# Patching CrimeScore Data: OK

# %%
# Patch the SizeRank Data
patch_sizerank = requests.patch(database_url, data=json.dumps(final_SizeRank))
print(f'Patching SizeRank Data: {patch_sizerank.reason}')
# Out:
# Patching SizeRank Data: OK

# %%
# Patch the HousingScore Dictionary
patch_housingscore = requests.patch(database_url, data=json.dumps(final_HousingScore))
print(f'Patching HousingScore Data: {patch_housingscore.reason}')
# Out:
# Patching HousingScore Data: OK

# %%
# Patch the AvgScrRead Dictionary
patch_avgscrread = requests.patch(database_url, data=json.dumps(final_AvgScrRead))
print(f'Patching AvgScrRead Data: {patch_avgscrread.reason}')
# Out:
# Patching AvgScrRead Data: OK

# %%
# Patch the AvgScrEng Dictionary
patch_avgscreng = requests.patch(database_url, data=json.dumps(final_AvgScrEng))
print(f'Patching AvgScrEng Data: {patch_avgscreng.reason}')
# Out:
# Patching AvgScrEng Data: OK

# %%
# Patch the AvgScrMath Dictionary
patch_avgscrmath = requests.patch(database_url, data=json.dumps(final_AvgScrMath))
print(f'Patching AvgScrMath Data: {patch_avgscrmath.reason}')
# Out:
# Patching AvgScrMath Data: OK

# %%
# Patch the AvgScrSci Dictionary
patch_avgscrsci = requests.patch(database_url, data=json.dumps(final_AvgScrSci))
print(f'Patching AvgScrSci Data: {patch_avgscrsci.reason}')
# Out:
# Patching AvgScrSci Data: OK

# %%
# Patch the AvgACT Dictionary
patch_avgact = requests.patch(database_url, data=json.dumps(final_AvgACT))
print(f'Patching AvgACT Data: {patch_avgact.reason}')
# Out:
# Patching AvgACT Data: OK
